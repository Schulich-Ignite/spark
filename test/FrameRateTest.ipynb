# %%
import spark
# %reload_ext spark

# Unit test for FRAME_RATE
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-cba4a2001c8b> in <module>
# ----> 1 import spark
#       2 get_ipython().run_line_magic('reload_ext', 'spark')
#       3
#       4 # Unit test for FRAME_RATE
#
# ModuleNotFoundError: No module named 'spark'

# %%
# %%ignite
#
# def setup():
#     size(200, 100)
#     background("light blue")
#     print("frame rate:", FRAME_RATE)
#     # this prints 30, the actual frame rate
# Out:
# Done drawing.
# Canvas(height=100, width=100)
# frame rate: 30

# %%
# %%ignite
#
# def setup():
#     size(200, 100)
#     background("light blue")
#     FRAME_RATE = 1
#     print("frame rate:", FRAME_RATE)
#     # this prints 1, not what I want
# Out:
# Done drawing.
# Canvas(height=100, width=100)
# frame rate: 1

# %%
# %%ignite
#
# def setup():
#     size(200, 100)
#     background("light blue")
#     print("frame rate:", FRAME_RATE)
#     FRAME_RATE = 10
#     # this gives an error, FRAME_RATE is referenced before assignment
# Out:
# Error in setup() function: local variable 'FRAME_RATE' referenced before assignment
# Canvas(height=100, width=100)
# \begin{Verbatim}[commandchars=\\\{\}]
#
# \end{Verbatim}
