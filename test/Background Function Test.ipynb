# %%
import spark
# %reload_ext spark

# %%
# %%ignite
#
# #This cell is for correct output from 3 arguments
# def setup():
#     size(400,400)
#     background(100,120,120)
# Out:
# Done drawing.
# Canvas(height=100, width=100)
# \begin{Verbatim}[commandchars=\\\{\}]
#
# \end{Verbatim}

# %%
# %%ignite
#
# #This cell is for correct output from 4 arguments(color is kept same to show alpha works)
# def setup():
#     size(400,400)
#     background(100,120,120,0.4)
# Out:
# Done drawing.
# Canvas(height=100, width=100)
# \begin{Verbatim}[commandchars=\\\{\}]
#
# \end{Verbatim}

# %%
# %%ignite
#
# #This cell is for correct output from 1 arguments(Hex code given in string form)
# def setup():
#     size(400,400)
#     background("#F0A2A2")
# Out:
# Done drawing.
# Canvas(height=100, width=100)
# \begin{Verbatim}[commandchars=\\\{\}]
#
# \end{Verbatim}

# %%
# %%ignite
#
# # This cell is automatically bounded between 0 and 255 when given ints outside range
# def setup():
#     size(400,400)
#     background(256,134,280)
# Out:
# Done drawing.
# Canvas(height=100, width=100)
# \begin{Verbatim}[commandchars=\\\{\}]
#
# \end{Verbatim}

# %%
# %%ignite
#
# # This cell is automatically bounded between 0 and 1.0 when given floats outside range
# def setup():
#     size(400,400)
#     background(226,134,210,2.1)
# Out:
# Done drawing.
# Canvas(height=100, width=100)
# \begin{Verbatim}[commandchars=\\\{\}]
#
# \end{Verbatim}

# %%
# %%ignite
#
# #This cell is correct output from 1 argument as rgb grey colour
# def setup():
#     size(400,400)
#     background(202)
# Out:
# Done drawing.
# Canvas(height=100, width=100)
# \begin{Verbatim}[commandchars=\\\{\}]
#
# \end{Verbatim}

# %%
# %%ignite
#
# #This cell is correct output from 1 argument as HTML rgb string
# def setup():
#     size(400, 400)
#     background("rgb(255, 0, 0)")
# Out:
# Done drawing.
# Canvas(height=100, width=100)
# \begin{Verbatim}[commandchars=\\\{\}]
#
# \end{Verbatim}

# %%
# %%ignite
#
# #This cell is incorrect output from 1 float arg
# def setup():
#     size(400,400)
#     background(202.0)
# Out:
# Done drawing.
# Canvas(height=100, width=100)
# \begin{Verbatim}[commandchars=\\\{\}]
#
# \end{Verbatim}

# %%
# %%ignite
#
# #This cell is incorrect output from 2 args
# def setup():
#     size(400,400)
#     background(202, 303)
# Out:
# Error in setup() function: background expected 1, 3, or 4 arguments, got 2
# Canvas(height=100, width=100)
# \begin{Verbatim}[commandchars=\\\{\}]
#
# \end{Verbatim}

# %%
# %%ignite
#
# # fill_style is not overwritten
# def setup():
#     size(400, 400)
#
#     fill_style('red')
#     background('blue')
#     rect(100, 100, 30, 50)
#
#     if canvas.fill_style != 'red':
#         raise Exception("Expected old fill_style to be restored at 'red', instead got {}".format(canvas.fill_style))
# Out:
# Done drawing.
# Canvas(height=100, width=100)
# \begin{Verbatim}[commandchars=\\\{\}]
#
# \end{Verbatim}

# %%
# %%ignite
#
# #This cell is demo & correct output for hsl
# def setup():
#     size(400, 400)
#
# color = 0
# def draw():
#     global color
#     background("hsl({}, 100%, 50%)".format(color))
#     color = (color+1)%360
# Out:
# Stopped
# Button(description='Stop', style=ButtonStyle())
# Canvas(height=100, width=100)
# \begin{Verbatim}[commandchars=\\\{\}]
#
# \end{Verbatim}

# %%
# %%ignite
#
# # This cell is automatically bounded between 0 and 1.0 when given floats outside range
# def setup():
#     size(400,400)
#     background(226,134,210,2.1)
# Out:
# Done drawing.
# Canvas(height=100, width=100)
# \begin{Verbatim}[commandchars=\\\{\}]
#
# \end{Verbatim}

# %%
# %%ignite
#
# #This cell is correct output from 1 argument as rgb grey colour
# def setup():
#     size(400,400)
#     background(202)
# Out:
# Done drawing.
# Canvas(height=100, width=100)
# \begin{Verbatim}[commandchars=\\\{\}]
#
# \end{Verbatim}

# %%
# %%ignite
#
# #This cell is incorrect output from 1 float arg
# def setup():
#     size(400,400)
#     background(202.0)
# Out:
# Done drawing.
# Canvas(height=100, width=100)
# \begin{Verbatim}[commandchars=\\\{\}]
#
# \end{Verbatim}

# %%
# %%ignite
#
# #This cell is incorrect output from 2 args
# def setup():
#     size(400,400)
#     background(202, 303)
# Out:
# Error in setup() function: background expected 1, 3, or 4 arguments, got 2
# Canvas(height=100, width=100)
# \begin{Verbatim}[commandchars=\\\{\}]
#
# \end{Verbatim}

# %%
# %%ignite
#
# # fill_style is not overwritten
# def setup():
#     size(400, 400)
#
#     fill_style('red')
#     background('blue')
#     rect(100, 100, 30, 50)
#
#     if canvas.fill_style != 'red':
#         raise Exception("Expected old fill_style to be restored at 'red', instead got {}".format(canvas.fill_style))
# Out:
# Done drawing.
# Canvas(height=100, width=100)
# \begin{Verbatim}[commandchars=\\\{\}]
#
# \end{Verbatim}
