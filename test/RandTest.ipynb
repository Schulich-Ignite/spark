# %%
import spark
# %reload_ext spark

# %%
# %%ignite
#
# x = 0
# vx = randint(10)-5
# y = 0
# vy = randint(10)-5
# if vx >= 0:
#     vx += 1
# if vy >= 0:
#     vy += 1
#
# def setup():
#     global x, y
#     size(500, 500)
#     x = width/2
#     y = width/2
#
# def draw():
#     global x, y, vx, vy
#     r = 30
#     if x < r:
#         x = r
#         vx = abs(vx)
#     elif x > width-r:
#         x = width-r
#         vx = -abs(vx)
#     else:
#         x += vx
#
#     if y < r:
#         y = r
#         vy = abs(vy)
#     elif y > height-r:
#         y = height-r
#         vy = -abs(vy)
#     else:
#         y += vy
#
#     background("black")
#     fill_style("white")
#     fill_circle(x, y, r)
# Out:
# Stopped
# Button(description='Stop', style=ButtonStyle())
# Canvas(height=100, width=100)
# \begin{Verbatim}[commandchars=\\\{\}]
#
# \end{Verbatim}
