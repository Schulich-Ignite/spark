# %%
import spark
# %reload_ext spark

# %%
# %%ignite
#
# from math import sin
#
# #This cell is for correct output from 3 arguments
# def setup():
#     size(400,400)
#     background(100,120,120)
#     fill_style("white")
#
# color = 0
# ball_x = 200
# ball_y = 200
# ball_vx = 2
# ball_vy = 2
# def draw():
#     global color
#     background(int(255*(sin(color*pi/180)/2+0.5)), int(255*(sin(((color+120)%360)*pi/180)/2+0.5)), int(255*(sin(((color+240)%360)*pi/180)/2+0.5)))
#     circle(ball_x, ball_y, 30)
#
# def key_pressed():
#     global color, ball_x, ball_y
#     color = (color + 1)%360
#     if key == 'ArrowLeft':
#         if ball_x - ball_vx >= 0:
#             ball_x -= ball_vx
#         else:
#             ball_x = 0
#     if key == 'ArrowRight':
#         if ball_x + ball_vx <= width:
#             ball_x += ball_vx
#         else:
#             ball_x = width
#     if key == 'ArrowUp':
#         if ball_y - ball_vy >= 0:
#             ball_y -= ball_vy
#         else:
#             ball_y = 0
#     if key == 'ArrowDown':
#         if ball_y + ball_vy <= height:
#             ball_y += ball_vy
#         else:
#             ball_y = height
#
# def mouse_down():
#     global ball_x, ball_y
#     ball_x, ball_y = (200, 200)
# Out:
# Running...
# Button(description='Stop', style=ButtonStyle())
# Canvas(height=100, width=100)
# mouse_down
